# %%
# 1. send a get to https://gisco-services.ec.europa.eu/dem/copernicus/outD/10_DEM_y40x10.zip
# 2. unpack

['10_DEM_y40x10.zip', '10_DEM_y40x20.zip', '10_DEM_y50x10.zip', '10_DEM_y50x20.zip']
# Out:
# ['10_DEM_y40x10.zip',
#  '10_DEM_y40x20.zip',
#  '10_DEM_y50x10.zip',
#  '10_DEM_y50x20.zip']
